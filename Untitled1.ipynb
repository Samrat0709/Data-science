# %% [markdown]
# <a href="https://colab.research.google.com/github/Samrat0709/Data-science/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd

# %%
ipl= pd.read_csv('/content/ipl-matches.csv')

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl[ipl['WonBy']=='Wickets'].shape[0]
# Out:
# 509

# %%
ipl[ipl['WonBy']=='Runs'].shape[0]
# Out:
# 423

# %%
year=ipl['Date'].apply(lambda x : x.split('-')[0])
ipl['Season']=year.copy()
ipl
# Out:
#           ID        City        Date Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29   2022        Final
# 1    1312199   Ahmedabad  2022-05-27   2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25   2022   Eliminator
# 3    1312197     Kolkata  2022-05-24   2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22   2022           70
# ..       ...         ...         ...    ...          ...
# 945   335986     Kolkata  2008-04-20   2008            4
# 946   335985      Mumbai  2008-04-20   2008            5
# 947   335984       Delhi  2008-04-19   2008            3
# 948   335983  Chandigarh  2008-04-19   2008            2
# 949   335982   Bangalore  2008-04-18   2008            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl[((ipl['Season']=='2017') & (ipl['TossDecision']=='field')) & (ipl['TossWinner']==ipl['WinningTeam'])].shape[0]
# Out:
# 28

# %%
ipl['Venue'].value_counts().index[0]
# Out:
# 'Eden Gardens'

# %%
ipl['MatchNumber'].value_counts()
# Out:
# Final                 15
# 36                    15
# 46                    15
# 45                    15
# 44                    15
#                       ..
# 65                     4
# Elimination Final      3
# 72                     2
# 71                     2
# 3rd Place Play-Off     1
# Name: MatchNumber, Length: 80, dtype: int64
